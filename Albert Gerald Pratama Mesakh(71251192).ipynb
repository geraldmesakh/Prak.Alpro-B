# %%
tinggi = float(input("Masukkan tinggi badan (meter): "))

bmi = float(input("Masukkan BMI yang diharapkan: "))

berat = bmi * (tinggi ** 2)

print("Berat badan yang diperlukan adalah:", round(berat, 2), "kg")
# Out:
# Masukkan tinggi badan (meter):  1.75
# Masukkan BMI yang diharapkan:  25
# Berat badan yang diperlukan adalah: 76.56 kg

# %%
x = int(input("Masukkan nilai x (bilangan bulat): "))

hasil = 2 * x**3 + 2 * x + 15 / x

print("Nilai f(x) adalah:", hasil)
# Out:
# Masukkan nilai x (bilangan bulat):  3
# Nilai f(x) adalah: 65.0

# %%
gaji_per_jam = float(input("Masukkan gaji per jam: "))
jam_per_minggu = float(input("Masukkan jumlah jam kerja per minggu: "))

total_jam = jam_per_minggu * 5

pendapatan_kotor = gaji_per_jam * total_jam

pajak = 0.14 * pendapatan_kotor

pendapatan_bersih = pendapatan_kotor - pajak

pakaian = 0.10 * pendapatan_bersih

alat_tulis = 0.01 * pendapatan_bersih

sisa_uang = pendapatan_bersih - pakaian - alat_tulis

sedekah = 0.25 * sisa_uang

anak_yatim = 0.30 * sedekah

kaum_dhuafa = sedekah - anak_yatim

print("\n===== HASIL PERHITUNGAN =====")
print("1. Pendapatan sebelum pajak       : Rp", pendapatan_kotor)
print("2. Pendapatan setelah pajak       : Rp", pendapatan_bersih)
print("3. Uang untuk pakaian & aksesoris : Rp", pakaian)
print("4. Uang untuk alat tulis          : Rp", alat_tulis)
print("5. Jumlah uang yang disedekahkan  : Rp", sedekah)
print("6. Untuk anak yatim               : Rp", anak_yatim)
print("7. Untuk kaum dhuafa              : Rp", kaum_dhuafa)
# Out:
# Masukkan gaji per jam:  20000
# Masukkan jumlah jam kerja per minggu:  8
# ===== HASIL PERHITUNGAN =====
# 1. Pendapatan sebelum pajak       : Rp 800000.0
# 2. Pendapatan setelah pajak       : Rp 688000.0
# 3. Uang untuk pakaian & aksesoris : Rp 68800.0
# 4. Uang untuk alat tulis          : Rp 6880.0
# 5. Jumlah uang yang disedekahkan  : Rp 153080.0
# 6. Untuk anak yatim               : Rp 45924.0
# 7. Untuk kaum dhuafa              : Rp 107156.0
